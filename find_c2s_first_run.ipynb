# %% [markdown]
# ### Imports

# %%
from datetime import datetime
from censys.search import CensysHosts
from pprint import pprint

# %% [markdown]
# ### Date to store first seen, last seen

# %%
datestr=datetime.today().strftime('%Y%m%d')
print(datestr)
# Out:
# 20230509

# %% [markdown]
# ### Dict to store c2 info

# %%
c2_data=dict()

# %% [markdown]
# ### creds to query censys API

# %%
API_ID='5b3a045d-903b-4d29-99b3-a7af51be9ac7'
api_secret='ied0oG1T2SdPkN6Q4mw0QHoRe5oIhLHX'
c=CensysHosts(API_ID, api_secret)

# %% [markdown]
# ### Look for new C2s:https://michaelkoczwara.medium.com/hunting-c2-with-shodan-223ca250d06f

# %% [markdown]
# ### Look for Havoc C2

# %%
family='havoc'
query='services.tls.certificates.leaf_data.subject.postal_code: 3540 and services.jarm.fingerprint: 3fd21b20d00000021c43d21b21b43de0a012c76cf078b8d06f4620c2286f5e'
output=c.search(query)
for page in output:
    for hit in page:
        c2_ip=hit['ip']
        c2_asn_desc=hit['autonomous_system']['description']
        if c2_ip not in c2_data:
            c2_data[c2_ip]={'family':family,'first_seen':datestr,'last_seen':datestr,'ASN':c2_asn_desc}
            if c2_ip in c2_data:
                #update the last seen date
                c2_data[c2_ip]['last_seen']=datestr
pprint(c2_data)
print(len(c2_data))
# Out:
# {'143.198.62.146': {'ASN': 'DIGITALOCEAN-ASN',
#                     'family': 'havoc',
#                     'first_seen': '20230509',
#                     'last_seen': '20230509'},
#  '143.42.110.206': {'ASN': 'AKAMAI-LINODE-AP Akamai Connected Cloud',
#                     'family': 'havoc',
#                     'first_seen': '20230509',
#                     'last_seen': '20230509'},
#  '157.245.199.109': {'ASN': 'DIGITALOCEAN-ASN',
#                      'family': 'havoc',
#                      'first_seen': '20230509',
#                      'last_seen': '20230509'},
#  '170.187.232.126': {'ASN': 'AKAMAI-LINODE-AP Akamai Connected Cloud',
#                      'family': 'havoc',
#                      'first_seen': '20230509',
#                      'last_seen': '20230509'},
#  '174.138.28.5': {'ASN': 'DIGITALOCEAN-ASN',
#                   'family': 'havoc',
#                   'first_seen': '20230509',
#                   'last_seen': '20230509'},
# ...

# %% [markdown]
# ### Look for Posh C2

# %%
family='posh'
query='P18055077'
output=c.search(query)
for page in output:
    for hit in page:
        c2_ip=hit['ip']
        c2_asn_desc=hit['autonomous_system']['description']
        if c2_ip not in c2_data:
            c2_data[c2_ip]={'family':family,'first_seen':datestr,'last_seen':datestr,'ASN':c2_asn_desc}
            if c2_ip in c2_data:
                #update the last seen date
                c2_data[c2_ip]['last_seen']=datestr
pprint(c2_data)
print(len(c2_data))
# Out:
# {'143.198.62.146': {'ASN': 'DIGITALOCEAN-ASN',
#                     'family': 'havoc',
#                     'first_seen': '20230509',
#                     'last_seen': '20230509'},
#  '143.42.110.206': {'ASN': 'AKAMAI-LINODE-AP Akamai Connected Cloud',
#                     'family': 'havoc',
#                     'first_seen': '20230509',
#                     'last_seen': '20230509'},
#  '157.245.199.109': {'ASN': 'DIGITALOCEAN-ASN',
#                      'family': 'havoc',
#                      'first_seen': '20230509',
#                      'last_seen': '20230509'},
#  '170.187.232.126': {'ASN': 'AKAMAI-LINODE-AP Akamai Connected Cloud',
#                      'family': 'havoc',
#                      'first_seen': '20230509',
#                      'last_seen': '20230509'},
#  '174.138.28.5': {'ASN': 'DIGITALOCEAN-ASN',
#                   'family': 'havoc',
#                   'first_seen': '20230509',
#                   'last_seen': '20230509'},
# ...

# %% [markdown]
# ### Look for sliver C2

# %%
family='sliver'
query='(services.jarm.fingerprint: 00000000000000000043d43d00043de2a97eabb398317329f027c66e4c1b01) and services.port=`31337`'
output=c.search(query)
for page in output:
    for hit in page:
        c2_ip=hit['ip']
        c2_asn_desc=hit['autonomous_system']['description']
        if c2_ip not in c2_data:
            c2_data[c2_ip]={'family':family,'first_seen':datestr,'last_seen':datestr,'ASN':c2_asn_desc}
            if c2_ip in c2_data:
                #update the last seen date
                c2_data[c2_ip]['last_seen']=datestr
pprint(c2_data)
print(len(c2_data))
# Out:
# {'1.13.174.161': {'ASN': 'TENCENT-NET-AP Shenzhen Tencent Computer Systems '
#                          'Company Limited',
#                   'family': 'sliver',
#                   'first_seen': '20230509',
#                   'last_seen': '20230509'},
#  '1.13.180.253': {'ASN': 'TENCENT-NET-AP Shenzhen Tencent Computer Systems '
#                          'Company Limited',
#                   'family': 'sliver',
#                   'first_seen': '20230509',
#                   'last_seen': '20230509'},
#  '101.33.248.33': {'ASN': 'TENCENT-NET-AP Shenzhen Tencent Computer Systems '
#                           'Company Limited',
#                    'family': 'sliver',
#                    'first_seen': '20230509',
#                    'last_seen': '20230509'},
#  '101.43.156.89': {'ASN': 'TENCENT-NET-AP Shenzhen Tencent Computer Systems '
#                           'Company Limited',
#                    'family': 'sliver',
#                    'first_seen': '20230509',
# ...

# %% [markdown]
# ### Look for Evilginx C2

# %%
family='Evilginx'
query='b18d778b4e4b6bf1fd5b2d790c941270145a6a6d'
output=c.search(query)
for page in output:
    for hit in page:
        c2_ip=hit['ip']
        c2_asn_desc=hit['autonomous_system']['description']
        if c2_ip not in c2_data:
            c2_data[c2_ip]={'family':family,'first_seen':datestr,'last_seen':datestr,'ASN':c2_asn_desc}
            if c2_ip in c2_data:
                #update the last seen date
                c2_data[c2_ip]['last_seen']=datestr
pprint(c2_data)
print(len(c2_data))
# Out:
# {'1.13.174.161': {'ASN': 'TENCENT-NET-AP Shenzhen Tencent Computer Systems '
#                          'Company Limited',
#                   'family': 'sliver',
#                   'first_seen': '20230509',
#                   'last_seen': '20230509'},
#  '1.13.180.253': {'ASN': 'TENCENT-NET-AP Shenzhen Tencent Computer Systems '
#                          'Company Limited',
#                   'family': 'sliver',
#                   'first_seen': '20230509',
#                   'last_seen': '20230509'},
#  '101.33.248.33': {'ASN': 'TENCENT-NET-AP Shenzhen Tencent Computer Systems '
#                           'Company Limited',
#                    'family': 'sliver',
#                    'first_seen': '20230509',
#                    'last_seen': '20230509'},
#  '101.43.156.89': {'ASN': 'TENCENT-NET-AP Shenzhen Tencent Computer Systems '
#                           'Company Limited',
#                    'family': 'sliver',
#                    'first_seen': '20230509',
# ...

# %% [markdown]
# ### Look for metasploit

# %%
family='metasploit'
query='MetasploitSelfSignedCA'
output=c.search(query)
for page in output:
    for hit in page:
        c2_ip=hit['ip']
        c2_asn_desc=hit['autonomous_system']['description']
        if c2_ip not in c2_data:
            c2_data[c2_ip]={'family':family,'first_seen':datestr,'last_seen':datestr,'ASN':c2_asn_desc}
            if c2_ip in c2_data:
                #update the last seen date
                c2_data[c2_ip]['last_seen']=datestr
pprint(c2_data)
print(len(c2_data))
# Out:
# {'1.117.38.101': {'ASN': 'TENCENT-NET-AP Shenzhen Tencent Computer Systems '
#                          'Company Limited',
#                   'family': 'metasploit',
#                   'first_seen': '20230509',
#                   'last_seen': '20230509'},
#  '1.13.174.161': {'ASN': 'TENCENT-NET-AP Shenzhen Tencent Computer Systems '
#                          'Company Limited',
#                   'family': 'sliver',
#                   'first_seen': '20230509',
#                   'last_seen': '20230509'},
#  '1.13.180.253': {'ASN': 'TENCENT-NET-AP Shenzhen Tencent Computer Systems '
#                          'Company Limited',
#                   'family': 'sliver',
#                   'first_seen': '20230509',
#                   'last_seen': '20230509'},
#  '1.15.186.229': {'ASN': 'TENCENT-NET-AP Shenzhen Tencent Computer Systems '
#                          'Company Limited',
#                   'family': 'metasploit',
#                   'first_seen': '20230509',
# ...

# %% [markdown]
# ### Look for mythic C2s
#
# https://twitter.com/TLP_R3D/status/1653427524364386306?cxt=HHwWhIC-udfkk_ItAAAA

# %%
family='mythic'
query='-859291042'
output=c.search(query)
for page in output:
    for hit in page:
        c2_ip=hit['ip']
        c2_asn_desc=hit['autonomous_system']['description']
        if c2_ip not in c2_data:
            c2_data[c2_ip]={'family':family,'first_seen':datestr,'last_seen':datestr,'ASN':c2_asn_desc}
            if c2_ip in c2_data:
                #update the last seen date
                c2_data[c2_ip]['last_seen']=datestr
pprint(c2_data)
print(len(c2_data))
# Out:
# {'1.117.38.101': {'ASN': 'TENCENT-NET-AP Shenzhen Tencent Computer Systems '
#                          'Company Limited',
#                   'family': 'metasploit',
#                   'first_seen': '20230509',
#                   'last_seen': '20230509'},
#  '1.13.174.161': {'ASN': 'TENCENT-NET-AP Shenzhen Tencent Computer Systems '
#                          'Company Limited',
#                   'family': 'sliver',
#                   'first_seen': '20230509',
#                   'last_seen': '20230509'},
#  '1.13.180.253': {'ASN': 'TENCENT-NET-AP Shenzhen Tencent Computer Systems '
#                          'Company Limited',
#                   'family': 'sliver',
#                   'first_seen': '20230509',
#                   'last_seen': '20230509'},
#  '1.15.186.229': {'ASN': 'TENCENT-NET-AP Shenzhen Tencent Computer Systems '
#                          'Company Limited',
#                   'family': 'metasploit',
#                   'first_seen': '20230509',
# ...

# %% [markdown]
# ### Look for PupyRAT C2s
#
# https://twitter.com/TLP_R3D/status/1654038822668075008

# %%
family='PupyRAT'
query='aa3939fc357723135870d5036b12a67097b03309'
output=c.search(query)
for page in output:
    for hit in page:
        c2_ip=hit['ip']
        c2_asn_desc=hit['autonomous_system']['description']
        if c2_ip not in c2_data:
            c2_data[c2_ip]={'family':family,'first_seen':datestr,'last_seen':datestr,'ASN':c2_asn_desc}
            if c2_ip in c2_data:
                #update the last seen date
                c2_data[c2_ip]['last_seen']=datestr
pprint(c2_data)
print(len(c2_data))
# Out:
# {'1.117.38.101': {'ASN': 'TENCENT-NET-AP Shenzhen Tencent Computer Systems '
#                          'Company Limited',
#                   'family': 'metasploit',
#                   'first_seen': '20230509',
#                   'last_seen': '20230509'},
#  '1.13.174.161': {'ASN': 'TENCENT-NET-AP Shenzhen Tencent Computer Systems '
#                          'Company Limited',
#                   'family': 'sliver',
#                   'first_seen': '20230509',
#                   'last_seen': '20230509'},
#  '1.13.180.253': {'ASN': 'TENCENT-NET-AP Shenzhen Tencent Computer Systems '
#                          'Company Limited',
#                   'family': 'sliver',
#                   'first_seen': '20230509',
#                   'last_seen': '20230509'},
#  '1.15.186.229': {'ASN': 'TENCENT-NET-AP Shenzhen Tencent Computer Systems '
#                          'Company Limited',
#                   'family': 'metasploit',
#                   'first_seen': '20230509',
# ...

# %% [markdown]
# ### Look for supershell C2s
#
# https://twitter.com/nahamike01/status/1643906047583879168?cxt=HHwWgIDUpeX1qdAtAAAA

# %%
family='supershell'
query='-695508679'
output=c.search(query)
for page in output:
    for hit in page:
        c2_ip=hit['ip']
        c2_asn_desc=hit['autonomous_system']['description']
        if c2_ip not in c2_data:
            c2_data[c2_ip]={'family':family,'first_seen':datestr,'last_seen':datestr,'ASN':c2_asn_desc}
            if c2_ip in c2_data:
                #update the last seen date
                c2_data[c2_ip]['last_seen']=datestr
pprint(c2_data)
print(len(c2_data))
# Out:
# {'1.117.38.101': {'ASN': 'TENCENT-NET-AP Shenzhen Tencent Computer Systems '
#                          'Company Limited',
#                   'family': 'metasploit',
#                   'first_seen': '20230509',
#                   'last_seen': '20230509'},
#  '1.13.174.161': {'ASN': 'TENCENT-NET-AP Shenzhen Tencent Computer Systems '
#                          'Company Limited',
#                   'family': 'sliver',
#                   'first_seen': '20230509',
#                   'last_seen': '20230509'},
#  '1.13.180.253': {'ASN': 'TENCENT-NET-AP Shenzhen Tencent Computer Systems '
#                          'Company Limited',
#                   'family': 'sliver',
#                   'first_seen': '20230509',
#                   'last_seen': '20230509'},
#  '1.15.186.229': {'ASN': 'TENCENT-NET-AP Shenzhen Tencent Computer Systems '
#                          'Company Limited',
#                   'family': 'metasploit',
#                   'first_seen': '20230509',
# ...

# %% [markdown]
# ### Look for cobalt strike C2s
#
# https://twitter.com/akaclandestine/status/1593975199531036672
#
# (looking for parsed cobalt strike C2s)

# %%
family='cobaltstrike'
query='Cobalt Strike Beacon'
output=c.search(query)
for page in output:
    for hit in page:
        c2_ip=hit['ip']
        c2_asn_desc=hit['autonomous_system']['description']
        if c2_ip not in c2_data:
            c2_data[c2_ip]={'family':family,'first_seen':datestr,'last_seen':datestr,'ASN':c2_asn_desc}
            if c2_ip in c2_data:
                #update the last seen date
                c2_data[c2_ip]['last_seen']=datestr
pprint(c2_data)
print(len(c2_data))
# Out:
# {'1.117.38.101': {'ASN': 'TENCENT-NET-AP Shenzhen Tencent Computer Systems '
#                          'Company Limited',
#                   'family': 'metasploit',
#                   'first_seen': '20230509',
#                   'last_seen': '20230509'},
#  '1.13.174.161': {'ASN': 'TENCENT-NET-AP Shenzhen Tencent Computer Systems '
#                          'Company Limited',
#                   'family': 'sliver',
#                   'first_seen': '20230509',
#                   'last_seen': '20230509'},
#  '1.13.180.253': {'ASN': 'TENCENT-NET-AP Shenzhen Tencent Computer Systems '
#                          'Company Limited',
#                   'family': 'sliver',
#                   'first_seen': '20230509',
#                   'last_seen': '20230509'},
#  '1.15.186.229': {'ASN': 'TENCENT-NET-AP Shenzhen Tencent Computer Systems '
#                          'Company Limited',
#                   'family': 'metasploit',
#                   'first_seen': '20230509',
# ...

# %% [markdown]
# ### Cobalt Strike (default cert)
#
# https://twitter.com/akaclandestine/status/1593975199531036672

# %%
family='cobaltstrike'
query='146473198'
output=c.search(query)
for page in output:
    for hit in page:
        c2_ip=hit['ip']
        c2_asn_desc=hit['autonomous_system']['description']
        if c2_ip not in c2_data:
            c2_data[c2_ip]={'family':family,'first_seen':datestr,'last_seen':datestr,'ASN':c2_asn_desc}
            if c2_ip in c2_data:
                #update the last seen date
                c2_data[c2_ip]['last_seen']=datestr
pprint(c2_data)
print(len(c2_data))
# Out:
# {'1.10.184.173': {'ASN': 'TOT-NET TOT Public Company Limited',
#                   'family': 'cobaltstrike',
#                   'first_seen': '20230509',
#                   'last_seen': '20230509'},
#  '1.10.190.242': {'ASN': 'TOT-NET TOT Public Company Limited',
#                   'family': 'cobaltstrike',
#                   'first_seen': '20230509',
#                   'last_seen': '20230509'},
#  '1.11.71.203': {'ASN': 'HELLONET-AS-KR LG HelloVision Corp.',
#                  'family': 'cobaltstrike',
#                  'first_seen': '20230509',
#                  'last_seen': '20230509'},
#  '1.117.38.101': {'ASN': 'TENCENT-NET-AP Shenzhen Tencent Computer Systems '
#                          'Company Limited',
#                   'family': 'metasploit',
#                   'first_seen': '20230509',
#                   'last_seen': '20230509'},
#  '1.13.174.161': {'ASN': 'TENCENT-NET-AP Shenzhen Tencent Computer Systems '
#                          'Company Limited',
# ...

# %% [markdown]
# ### Cobalt Strike (JARM hash)
#
# https://twitter.com/akaclandestine/status/1593975199531036672

# %%
family='cobaltstrike'
query='07d14d16d21d21d07c42d41d00041d24a458a375eef0c576d23a7bab9a9fb1'
output=c.search(query)
for page in output:
    for hit in page:
        c2_ip=hit['ip']
        c2_asn_desc=hit['autonomous_system']['description']
        if c2_ip not in c2_data:
            c2_data[c2_ip]={'family':family,'first_seen':datestr,'last_seen':datestr,'ASN':c2_asn_desc}
            if c2_ip in c2_data:
                #update the last seen date
                c2_data[c2_ip]['last_seen']=datestr
pprint(c2_data)
print(len(c2_data))
# Out:
# {'1.10.184.173': {'ASN': 'TOT-NET TOT Public Company Limited',
#                   'family': 'cobaltstrike',
#                   'first_seen': '20230509',
#                   'last_seen': '20230509'},
#  '1.10.190.242': {'ASN': 'TOT-NET TOT Public Company Limited',
#                   'family': 'cobaltstrike',
#                   'first_seen': '20230509',
#                   'last_seen': '20230509'},
#  '1.11.71.203': {'ASN': 'HELLONET-AS-KR LG HelloVision Corp.',
#                  'family': 'cobaltstrike',
#                  'first_seen': '20230509',
#                  'last_seen': '20230509'},
#  '1.117.38.101': {'ASN': 'TENCENT-NET-AP Shenzhen Tencent Computer Systems '
#                          'Company Limited',
#                   'family': 'metasploit',
#                   'first_seen': '20230509',
#                   'last_seen': '20230509'},
#  '1.13.174.161': {'ASN': 'TENCENT-NET-AP Shenzhen Tencent Computer Systems '
#                          'Company Limited',
# ...

# %% [markdown]
# ### Look for deimos C2s
#
# https://cyberwarzone.com/use-shodan-to-find-posh-c2-and-deimos-c2/

# %%
family='deimos'
query='-14029177'
output=c.search(query)
for page in output:
    for hit in page:
        c2_ip=hit['ip']
        c2_asn_desc=hit['autonomous_system']['description']
        if c2_ip not in c2_data:
            c2_data[c2_ip]={'family':family,'first_seen':datestr,'last_seen':datestr,'ASN':c2_asn_desc}
            if c2_ip in c2_data:
                #update the last seen date
                c2_data[c2_ip]['last_seen']=datestr
pprint(c2_data)
print(len(c2_data))
# Out:
# {'1.10.184.173': {'ASN': 'TOT-NET TOT Public Company Limited',
#                   'family': 'cobaltstrike',
#                   'first_seen': '20230509',
#                   'last_seen': '20230509'},
#  '1.10.190.242': {'ASN': 'TOT-NET TOT Public Company Limited',
#                   'family': 'cobaltstrike',
#                   'first_seen': '20230509',
#                   'last_seen': '20230509'},
#  '1.11.71.203': {'ASN': 'HELLONET-AS-KR LG HelloVision Corp.',
#                  'family': 'cobaltstrike',
#                  'first_seen': '20230509',
#                  'last_seen': '20230509'},
#  '1.117.38.101': {'ASN': 'TENCENT-NET-AP Shenzhen Tencent Computer Systems '
#                          'Company Limited',
#                   'family': 'metasploit',
#                   'first_seen': '20230509',
#                   'last_seen': '20230509'},
#  '1.13.174.161': {'ASN': 'TENCENT-NET-AP Shenzhen Tencent Computer Systems '
#                          'Company Limited',
# ...

# %% [markdown]
# ### Look for Misha stealer C2s
#
# https://blog.bushidotoken.net/2022/11/detecting-and-fingerprinting.html

# %%
family='deimos'
query='misha and UIKit'
output=c.search(query)
for page in output:
    for hit in page:
        c2_ip=hit['ip']
        c2_asn_desc=hit['autonomous_system']['description']
        if c2_ip not in c2_data:
            c2_data[c2_ip]={'family':family,'first_seen':datestr,'last_seen':datestr,'ASN':c2_asn_desc}
            if c2_ip in c2_data:
                #update the last seen date
                c2_data[c2_ip]['last_seen']=datestr
pprint(c2_data)
print(len(c2_data))
# Out:
# {'1.10.184.173': {'ASN': 'TOT-NET TOT Public Company Limited',
#                   'family': 'cobaltstrike',
#                   'first_seen': '20230509',
#                   'last_seen': '20230509'},
#  '1.10.190.242': {'ASN': 'TOT-NET TOT Public Company Limited',
#                   'family': 'cobaltstrike',
#                   'first_seen': '20230509',
#                   'last_seen': '20230509'},
#  '1.11.71.203': {'ASN': 'HELLONET-AS-KR LG HelloVision Corp.',
#                  'family': 'cobaltstrike',
#                  'first_seen': '20230509',
#                  'last_seen': '20230509'},
#  '1.117.38.101': {'ASN': 'TENCENT-NET-AP Shenzhen Tencent Computer Systems '
#                          'Company Limited',
#                   'family': 'metasploit',
#                   'first_seen': '20230509',
#                   'last_seen': '20230509'},
#  '1.13.174.161': {'ASN': 'TENCENT-NET-AP Shenzhen Tencent Computer Systems '
#                          'Company Limited',
# ...

# %% [markdown]
# ### Look for Collector Stealer C2s
#
# https://blog.bushidotoken.net/2022/11/detecting-and-fingerprinting.html

# %%
family='collector_stealer'
query='Collector Stealer'
output=c.search(query)
for page in output:
    for hit in page:
        c2_ip=hit['ip']
        c2_asn_desc=hit['autonomous_system']['description']
        if c2_ip not in c2_data:
            c2_data[c2_ip]={'family':family,'first_seen':datestr,'last_seen':datestr,'ASN':c2_asn_desc}
            if c2_ip in c2_data:
                #update the last seen date
                c2_data[c2_ip]['last_seen']=datestr
pprint(c2_data)
print(len(c2_data))
# Out:
# {'1.10.184.173': {'ASN': 'TOT-NET TOT Public Company Limited',
#                   'family': 'cobaltstrike',
#                   'first_seen': '20230509',
#                   'last_seen': '20230509'},
#  '1.10.190.242': {'ASN': 'TOT-NET TOT Public Company Limited',
#                   'family': 'cobaltstrike',
#                   'first_seen': '20230509',
#                   'last_seen': '20230509'},
#  '1.11.71.203': {'ASN': 'HELLONET-AS-KR LG HelloVision Corp.',
#                  'family': 'cobaltstrike',
#                  'first_seen': '20230509',
#                  'last_seen': '20230509'},
#  '1.117.38.101': {'ASN': 'TENCENT-NET-AP Shenzhen Tencent Computer Systems '
#                          'Company Limited',
#                   'family': 'metasploit',
#                   'first_seen': '20230509',
#                   'last_seen': '20230509'},
#  '1.13.174.161': {'ASN': 'TENCENT-NET-AP Shenzhen Tencent Computer Systems '
#                          'Company Limited',
# ...

# %% [markdown]
# ### Look for Titan Stealer C2s
#
# https://blog.bushidotoken.net/2022/11/detecting-and-fingerprinting.html

# %%
family='titan_stealer'
query='Titan Stealer'
output=c.search(query)
for page in output:
    for hit in page:
        c2_ip=hit['ip']
        c2_asn_desc=hit['autonomous_system']['description']
        if c2_ip not in c2_data:
            c2_data[c2_ip]={'family':family,'first_seen':datestr,'last_seen':datestr,'ASN':c2_asn_desc}
            if c2_ip in c2_data:
                #update the last seen date
                c2_data[c2_ip]['last_seen']=datestr
pprint(c2_data)
print(len(c2_data))
# Out:
# {'1.10.184.173': {'ASN': 'TOT-NET TOT Public Company Limited',
#                   'family': 'cobaltstrike',
#                   'first_seen': '20230509',
#                   'last_seen': '20230509'},
#  '1.10.190.242': {'ASN': 'TOT-NET TOT Public Company Limited',
#                   'family': 'cobaltstrike',
#                   'first_seen': '20230509',
#                   'last_seen': '20230509'},
#  '1.11.71.203': {'ASN': 'HELLONET-AS-KR LG HelloVision Corp.',
#                  'family': 'cobaltstrike',
#                  'first_seen': '20230509',
#                  'last_seen': '20230509'},
#  '1.117.38.101': {'ASN': 'TENCENT-NET-AP Shenzhen Tencent Computer Systems '
#                          'Company Limited',
#                   'family': 'metasploit',
#                   'first_seen': '20230509',
#                   'last_seen': '20230509'},
#  '1.13.174.161': {'ASN': 'TENCENT-NET-AP Shenzhen Tencent Computer Systems '
#                          'Company Limited',
# ...

# %% [markdown]
# ### Look for Patriot Stealer C2s
# https://blog.bushidotoken.net/2022/11/detecting-and-fingerprinting.html

# %%
family='patriot_stealer'
query='274603478'
output=c.search(query)
for page in output:
    for hit in page:
        c2_ip=hit['ip']
        c2_asn_desc=hit['autonomous_system']['description']
        if c2_ip not in c2_data:
            c2_data[c2_ip]={'family':family,'first_seen':datestr,'last_seen':datestr,'ASN':c2_asn_desc}
            if c2_ip in c2_data:
                #update the last seen date
                c2_data[c2_ip]['last_seen']=datestr
pprint(c2_data)
print(len(c2_data))
# Out:
# {'1.10.184.173': {'ASN': 'TOT-NET TOT Public Company Limited',
#                   'family': 'cobaltstrike',
#                   'first_seen': '20230509',
#                   'last_seen': '20230509'},
#  '1.10.190.242': {'ASN': 'TOT-NET TOT Public Company Limited',
#                   'family': 'cobaltstrike',
#                   'first_seen': '20230509',
#                   'last_seen': '20230509'},
#  '1.11.71.203': {'ASN': 'HELLONET-AS-KR LG HelloVision Corp.',
#                  'family': 'cobaltstrike',
#                  'first_seen': '20230509',
#                  'last_seen': '20230509'},
#  '1.117.38.101': {'ASN': 'TENCENT-NET-AP Shenzhen Tencent Computer Systems '
#                          'Company Limited',
#                   'family': 'metasploit',
#                   'first_seen': '20230509',
#                   'last_seen': '20230509'},
#  '1.13.174.161': {'ASN': 'TENCENT-NET-AP Shenzhen Tencent Computer Systems '
#                          'Company Limited',
# ...

# %% [markdown]
# ### Look for RAXNET Bitcoin Stealer C2s
#
# https://blog.bushidotoken.net/2022/11/detecting-and-fingerprinting.html

# %%
family='RAXNET_bitcoin_stealer'
query='-1236243965'
output=c.search(query)
for page in output:
    for hit in page:
        c2_ip=hit['ip']
        c2_asn_desc=hit['autonomous_system']['description']
        if c2_ip not in c2_data:
            c2_data[c2_ip]={'family':family,'first_seen':datestr,'last_seen':datestr,'ASN':c2_asn_desc}
            if c2_ip in c2_data:
                #update the last seen date
                c2_data[c2_ip]['last_seen']=datestr
pprint(c2_data)
print(len(c2_data))
# Out:
# {'1.10.184.173': {'ASN': 'TOT-NET TOT Public Company Limited',
#                   'family': 'cobaltstrike',
#                   'first_seen': '20230509',
#                   'last_seen': '20230509'},
#  '1.10.190.242': {'ASN': 'TOT-NET TOT Public Company Limited',
#                   'family': 'cobaltstrike',
#                   'first_seen': '20230509',
#                   'last_seen': '20230509'},
#  '1.11.71.203': {'ASN': 'HELLONET-AS-KR LG HelloVision Corp.',
#                  'family': 'cobaltstrike',
#                  'first_seen': '20230509',
#                  'last_seen': '20230509'},
#  '1.117.38.101': {'ASN': 'TENCENT-NET-AP Shenzhen Tencent Computer Systems '
#                          'Company Limited',
#                   'family': 'metasploit',
#                   'first_seen': '20230509',
#                   'last_seen': '20230509'},
#  '1.13.174.161': {'ASN': 'TENCENT-NET-AP Shenzhen Tencent Computer Systems '
#                          'Company Limited',
# ...

# %% [markdown]
# ### Pickle C2 data

# %%
import pickle
output = open('c2_data.pkl', 'wb')
pickle.dump(c2_data, output)
output.close()
# to read in c2 data:
#import pprint, pickle
#pkl_file = open('pkl.pkl', 'rb')
#data1 = pickle.load(pkl_file)
#pprint.pprint(data1)
#data2 = pickle.load(pkl_file)
#pprint.pprint(data2)
#pkl_file.close()
